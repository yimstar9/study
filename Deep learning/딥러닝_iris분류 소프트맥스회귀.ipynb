# %%
import os
import tensorflow.compat.v1 as tf
#os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
#os.environ["CUDA_VISIBLE_DEVICES"] = "0"
#tf.debugging.set_log_device_placement(True)
from SyncRNG import SyncRNG
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import LabelEncoder

# %%
# 데이터 불러오기
raw_data = pd.read_csv('E:/GoogleDrive/포트폴리오/A5팀 R과 Python기반 머신러닝과 딥러닝 분석 비교(12월22일)/dataset/iris.csv')
class_names = ['Setosa','Versicolor','Virginica']

# 데이터 셋  7:3 으로 분할
v=list(range(1,len(raw_data)+1))
s=SyncRNG(seed=38)
ord=s.shuffle(v)
idx=ord[:round(len(raw_data)*0.7)]

# R에서는 데이터프레임이 1부터 시작하기 때문에
# python에서 0행과 R에서 1행이 같은 원리로
# 같은 인덱스 번호를 가진다면 -1을 해주어 같은 데이터를 가지고 오게 한다.
# 인덱스 수정-R이랑 같은 데이터 가져오려고
for i in range(0,len(idx)):
    idx[i]=idx[i]-1

# 학습데이터, 테스트데이터 생성
train=raw_data.loc[idx] # 70%
#train=train.sort_index(ascending=True)
test=raw_data.drop(idx) # 30%

x_train = np.array(train.iloc[:,0:4], dtype=np.float32)
y_train = np.array(train.Species.replace(['setosa','versicolor','virginica'],[0,1,2]))
x_test = np.array(test.iloc[:,0:4], dtype=np.float32)
y_test = np.array(test.Species.replace(['setosa','versicolor','virginica'],[0,1,2]))

y_train_encoded = tf.keras.utils.to_categorical(y_train)
y_test_encoded = tf.keras.utils.to_categorical(y_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense


model = Sequential()
model.add(Dense(3, input_dim=4, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
history = model.fit(x_train, y_train_encoded, epochs=100, batch_size=2, validation_data=(x_test, y_test_encoded))

epochs = range(1, len(history.history['accuracy']) + 1)
plt.plot(epochs, history.history['loss'])
plt.plot(epochs, history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'pred'], loc='upper left')
plt.show()
print("\n 테스트 loss: %.4f" % (model.evaluate(x_test, y_test_encoded)[0]))
print("\n 테스트 accuracy: %.4f" % (model.evaluate(x_test, y_test_encoded)[1]))
# Out:
# Epoch 1/100
# 53/53 [==============================] - 0s 5ms/step - loss: 1.7069 - accuracy: 0.3333 - val_loss: 1.5693 - val_accuracy: 0.3333
# Epoch 2/100
# 53/53 [==============================] - 0s 4ms/step - loss: 1.4060 - accuracy: 0.3333 - val_loss: 1.3205 - val_accuracy: 0.3333
# Epoch 3/100
# 53/53 [==============================] - 0s 3ms/step - loss: 1.2165 - accuracy: 0.3238 - val_loss: 1.1537 - val_accuracy: 0.3111
# Epoch 4/100
# 53/53 [==============================] - 0s 3ms/step - loss: 1.0954 - accuracy: 0.1810 - val_loss: 1.0489 - val_accuracy: 0.3111
# Epoch 5/100
# 53/53 [==============================] - 0s 3ms/step - loss: 1.0117 - accuracy: 0.1714 - val_loss: 0.9780 - val_accuracy: 0.1778
# Epoch 6/100
# 53/53 [==============================] - 0s 4ms/step - loss: 0.9606 - accuracy: 0.1143 - val_loss: 0.9303 - val_accuracy: 0.1778
# Epoch 7/100
# 53/53 [==============================] - 0s 3ms/step - loss: 0.9219 - accuracy: 0.2095 - val_loss: 0.8975 - val_accuracy: 0.3556
# Epoch 8/100
# 53/53 [==============================] - 0s 4ms/step - loss: 0.8922 - accuracy: 0.3238 - val_loss: 0.8662 - val_accuracy: 0.4000
# Epoch 9/100
# 53/53 [==============================] - 0s 3ms/step - loss: 0.8650 - accuracy: 0.3810 - val_loss: 0.8429 - val_accuracy: 0.4444
# Epoch 10/100
# 53/53 [==============================] - 0s 3ms/step - loss: 0.8458 - accuracy: 0.4000 - val_loss: 0.8216 - val_accuracy: 0.4444
# Epoch 11/100
# 53/53 [==============================] - 0s 3ms/step - loss: 0.8237 - accuracy: 0.4381 - val_loss: 0.7962 - val_accuracy: 0.3778
# Epoch 12/100
# 53/53 [==============================] - 0s 3ms/step - loss: 0.7985 - accuracy: 0.4095 - val_loss: 0.7806 - val_accuracy: 0.4444
# Epoch 13/100
# 53/53 [==============================] - 0s 3ms/step - loss: 0.7795 - accuracy: 0.4095 - val_loss: 0.7630 - val_accuracy: 0.4667
# Epoch 14/100
# 53/53 [==============================] - 0s 3ms/step - loss: 0.7648 - accuracy: 0.4476 - val_loss: 0.7459 - val_accuracy: 0.4222
# Epoch 15/100
# 53/53 [==============================] - 0s 3ms/step - loss: 0.7458 - accuracy: 0.4667 - val_loss: 0.7302 - val_accuracy: 0.4222
# Epoch 16/100
# 53/53 [==============================] - 0s 3ms/step - loss: 0.7366 - accuracy: 0.4095 - val_loss: 0.7170 - val_accuracy: 0.4222
# Epoch 17/100
# 53/53 [==============================] - 0s 3ms/step - loss: 0.7166 - accuracy: 0.4952 - val_loss: 0.7021 - val_accuracy: 0.4222
# Epoch 18/100
# 53/53 [==============================] - 0s 3ms/step - loss: 0.7050 - accuracy: 0.4952 - val_loss: 0.6912 - val_accuracy: 0.4444
# Epoch 19/100
# 53/53 [==============================] - 0s 3ms/step - loss: 0.6911 - accuracy: 0.4667 - val_loss: 0.6793 - val_accuracy: 0.4667
# Epoch 20/100
# 53/53 [==============================] - 0s 3ms/step - loss: 0.6806 - accuracy: 0.5333 - val_loss: 0.6683 - val_accuracy: 0.4889
# Epoch 21/100
# 53/53 [==============================] - 0s 3ms/step - loss: 0.6716 - accuracy: 0.4857 - val_loss: 0.6590 - val_accuracy: 0.4667
# Epoch 22/100
# 53/53 [==============================] - 0s 3ms/step - loss: 0.6599 - accuracy: 0.5143 - val_loss: 0.6481 - val_accuracy: 0.5111
# Epoch 23/100
# 53/53 [==============================] - 0s 3ms/step - loss: 0.6494 - accuracy: 0.5619 - val_loss: 0.6402 - val_accuracy: 0.4889
# Epoch 24/100
# 53/53 [==============================] - 0s 3ms/step - loss: 0.6418 - accuracy: 0.4762 - val_loss: 0.6319 - val_accuracy: 0.5111
# Epoch 25/100
# 53/53 [==============================] - 0s 3ms/step - loss: 0.6374 - accuracy: 0.5429 - val_loss: 0.6226 - val_accuracy: 0.5111
# Epoch 26/100
# 53/53 [==============================] - 0s 3ms/step - loss: 0.6274 - accuracy: 0.5905 - val_loss: 0.6156 - val_accuracy: 0.5111
# Epoch 27/100
# 53/53 [==============================] - 0s 4ms/step - loss: 0.6150 - accuracy: 0.6000 - val_loss: 0.6070 - val_accuracy: 0.5556
# Epoch 28/100
# 53/53 [==============================] - 0s 4ms/step - loss: 0.6120 - accuracy: 0.5714 - val_loss: 0.5997 - val_accuracy: 0.6000
# Epoch 29/100
# 53/53 [==============================] - 0s 3ms/step - loss: 0.6051 - accuracy: 0.5905 - val_loss: 0.5931 - val_accuracy: 0.5556
# Epoch 30/100
# 53/53 [==============================] - 0s 3ms/step - loss: 0.5951 - accuracy: 0.6095 - val_loss: 0.5863 - val_accuracy: 0.5778
# Epoch 31/100
# 53/53 [==============================] - 0s 3ms/step - loss: 0.5881 - accuracy: 0.6000 - val_loss: 0.5804 - val_accuracy: 0.5778
# Epoch 32/100
# 53/53 [==============================] - 0s 3ms/step - loss: 0.5856 - accuracy: 0.6190 - val_loss: 0.5758 - val_accuracy: 0.5778
# Epoch 33/100
# 53/53 [==============================] - 0s 3ms/step - loss: 0.5771 - accuracy: 0.6190 - val_loss: 0.5688 - val_accuracy: 0.5778
# Epoch 34/100
# 53/53 [==============================] - 0s 4ms/step - loss: 0.5691 - accuracy: 0.5810 - val_loss: 0.5645 - val_accuracy: 0.6000
# Epoch 35/100
# 53/53 [==============================] - 0s 4ms/step - loss: 0.5685 - accuracy: 0.6286 - val_loss: 0.5574 - val_accuracy: 0.6444
# Epoch 36/100
# 53/53 [==============================] - 0s 3ms/step - loss: 0.5589 - accuracy: 0.6190 - val_loss: 0.5540 - val_accuracy: 0.6000
# Epoch 37/100
# 53/53 [==============================] - 0s 3ms/step - loss: 0.5544 - accuracy: 0.6381 - val_loss: 0.5471 - val_accuracy: 0.6444
# Epoch 38/100
# 53/53 [==============================] - 0s 3ms/step - loss: 0.5481 - accuracy: 0.6476 - val_loss: 0.5429 - val_accuracy: 0.6889
# Epoch 39/100
# 53/53 [==============================] - 0s 3ms/step - loss: 0.5442 - accuracy: 0.6571 - val_loss: 0.5390 - val_accuracy: 0.6889
# Epoch 40/100
# 53/53 [==============================] - 0s 3ms/step - loss: 0.5389 - accuracy: 0.6476 - val_loss: 0.5335 - val_accuracy: 0.7111
# Epoch 41/100
# 53/53 [==============================] - 0s 3ms/step - loss: 0.5343 - accuracy: 0.6381 - val_loss: 0.5305 - val_accuracy: 0.7111
# Epoch 42/100
# 53/53 [==============================] - 0s 3ms/step - loss: 0.5306 - accuracy: 0.6571 - val_loss: 0.5258 - val_accuracy: 0.7333
# Epoch 43/100
# 53/53 [==============================] - 0s 3ms/step - loss: 0.5268 - accuracy: 0.6476 - val_loss: 0.5206 - val_accuracy: 0.7333
# Epoch 44/100
# 53/53 [==============================] - 0s 3ms/step - loss: 0.5249 - accuracy: 0.6857 - val_loss: 0.5171 - val_accuracy: 0.7556
# Epoch 45/100
# 53/53 [==============================] - 0s 3ms/step - loss: 0.5187 - accuracy: 0.7143 - val_loss: 0.5143 - val_accuracy: 0.7556
# Epoch 46/100
# 53/53 [==============================] - 0s 3ms/step - loss: 0.5124 - accuracy: 0.6857 - val_loss: 0.5085 - val_accuracy: 0.6667
# Epoch 47/100
# 53/53 [==============================] - 0s 4ms/step - loss: 0.5130 - accuracy: 0.6762 - val_loss: 0.5058 - val_accuracy: 0.7778
# Epoch 48/100
# 53/53 [==============================] - 0s 3ms/step - loss: 0.5131 - accuracy: 0.6571 - val_loss: 0.5008 - val_accuracy: 0.6889
# Epoch 49/100
# 53/53 [==============================] - 0s 3ms/step - loss: 0.5048 - accuracy: 0.7429 - val_loss: 0.4989 - val_accuracy: 0.8444
# Epoch 50/100
# 53/53 [==============================] - 0s 3ms/step - loss: 0.4991 - accuracy: 0.6762 - val_loss: 0.4944 - val_accuracy: 0.7778
# Epoch 51/100
# 53/53 [==============================] - 0s 3ms/step - loss: 0.4954 - accuracy: 0.6857 - val_loss: 0.4915 - val_accuracy: 0.8444
# Epoch 52/100
# 53/53 [==============================] - 0s 3ms/step - loss: 0.4915 - accuracy: 0.7714 - val_loss: 0.4881 - val_accuracy: 0.8000
# Epoch 53/100
# 53/53 [==============================] - 0s 4ms/step - loss: 0.4878 - accuracy: 0.7048 - val_loss: 0.4845 - val_accuracy: 0.8000
# Epoch 54/100
# 53/53 [==============================] - 0s 3ms/step - loss: 0.4862 - accuracy: 0.7143 - val_loss: 0.4815 - val_accuracy: 0.8222
# Epoch 55/100
# 53/53 [==============================] - 0s 3ms/step - loss: 0.4822 - accuracy: 0.6857 - val_loss: 0.4777 - val_accuracy: 0.8222
# Epoch 56/100
# 53/53 [==============================] - 0s 3ms/step - loss: 0.4793 - accuracy: 0.7048 - val_loss: 0.4758 - val_accuracy: 0.8667
# Epoch 57/100
# 53/53 [==============================] - 0s 3ms/step - loss: 0.4756 - accuracy: 0.7905 - val_loss: 0.4739 - val_accuracy: 0.8889
# Epoch 58/100
# 53/53 [==============================] - 0s 3ms/step - loss: 0.4716 - accuracy: 0.7429 - val_loss: 0.4699 - val_accuracy: 0.8889
# Epoch 59/100
# 53/53 [==============================] - 0s 3ms/step - loss: 0.4708 - accuracy: 0.7810 - val_loss: 0.4665 - val_accuracy: 0.8667
# Epoch 60/100
# 53/53 [==============================] - 0s 4ms/step - loss: 0.4672 - accuracy: 0.7238 - val_loss: 0.4636 - val_accuracy: 0.8667
# Epoch 61/100
# 53/53 [==============================] - 0s 3ms/step - loss: 0.4636 - accuracy: 0.7810 - val_loss: 0.4608 - val_accuracy: 0.8889
# Epoch 62/100
# 53/53 [==============================] - 0s 3ms/step - loss: 0.4596 - accuracy: 0.7619 - val_loss: 0.4590 - val_accuracy: 0.8889
# Epoch 63/100
# 53/53 [==============================] - 0s 3ms/step - loss: 0.4588 - accuracy: 0.8381 - val_loss: 0.4556 - val_accuracy: 0.8889
# Epoch 64/100
# 53/53 [==============================] - 0s 3ms/step - loss: 0.4589 - accuracy: 0.7810 - val_loss: 0.4530 - val_accuracy: 0.9333
# Epoch 65/100
# 53/53 [==============================] - 0s 3ms/step - loss: 0.4546 - accuracy: 0.7524 - val_loss: 0.4503 - val_accuracy: 0.9333
# Epoch 66/100
# 53/53 [==============================] - 0s 3ms/step - loss: 0.4512 - accuracy: 0.8190 - val_loss: 0.4501 - val_accuracy: 0.9111
# Epoch 67/100
# 53/53 [==============================] - 0s 3ms/step - loss: 0.4474 - accuracy: 0.8095 - val_loss: 0.4454 - val_accuracy: 0.9333
# Epoch 68/100
# 53/53 [==============================] - 0s 3ms/step - loss: 0.4444 - accuracy: 0.7905 - val_loss: 0.4422 - val_accuracy: 0.9333
# Epoch 69/100
# 53/53 [==============================] - 0s 3ms/step - loss: 0.4455 - accuracy: 0.8095 - val_loss: 0.4417 - val_accuracy: 0.8889
# Epoch 70/100
# 53/53 [==============================] - 0s 3ms/step - loss: 0.4422 - accuracy: 0.8095 - val_loss: 0.4388 - val_accuracy: 0.8889
# Epoch 71/100
# 53/53 [==============================] - 0s 3ms/step - loss: 0.4383 - accuracy: 0.8476 - val_loss: 0.4367 - val_accuracy: 0.8889
# Epoch 72/100
# 53/53 [==============================] - 0s 3ms/step - loss: 0.4366 - accuracy: 0.7905 - val_loss: 0.4329 - val_accuracy: 0.9333
# Epoch 73/100
# 53/53 [==============================] - 0s 3ms/step - loss: 0.4323 - accuracy: 0.8857 - val_loss: 0.4315 - val_accuracy: 0.9333
# Epoch 74/100
# 53/53 [==============================] - 0s 3ms/step - loss: 0.4304 - accuracy: 0.8571 - val_loss: 0.4286 - val_accuracy: 0.9333
# Epoch 75/100
# 53/53 [==============================] - 0s 5ms/step - loss: 0.4283 - accuracy: 0.8762 - val_loss: 0.4267 - val_accuracy: 0.9333
# Epoch 76/100
# 53/53 [==============================] - 0s 3ms/step - loss: 0.4274 - accuracy: 0.8667 - val_loss: 0.4232 - val_accuracy: 0.9333
# Epoch 77/100
# 53/53 [==============================] - 0s 3ms/step - loss: 0.4237 - accuracy: 0.8667 - val_loss: 0.4215 - val_accuracy: 0.9333
# Epoch 78/100
# 53/53 [==============================] - 0s 3ms/step - loss: 0.4230 - accuracy: 0.8476 - val_loss: 0.4190 - val_accuracy: 0.9333
# Epoch 79/100
# 53/53 [==============================] - 0s 3ms/step - loss: 0.4189 - accuracy: 0.9048 - val_loss: 0.4184 - val_accuracy: 0.9333
# Epoch 80/100
# 53/53 [==============================] - 0s 3ms/step - loss: 0.4158 - accuracy: 0.8952 - val_loss: 0.4154 - val_accuracy: 0.9333
# Epoch 81/100
# 53/53 [==============================] - 0s 3ms/step - loss: 0.4149 - accuracy: 0.8952 - val_loss: 0.4135 - val_accuracy: 0.9333
# Epoch 82/100
# 53/53 [==============================] - 0s 3ms/step - loss: 0.4118 - accuracy: 0.8762 - val_loss: 0.4105 - val_accuracy: 0.9556
# Epoch 83/100
# 53/53 [==============================] - 0s 4ms/step - loss: 0.4097 - accuracy: 0.9048 - val_loss: 0.4094 - val_accuracy: 0.9333
# Epoch 84/100
# 53/53 [==============================] - 0s 3ms/step - loss: 0.4079 - accuracy: 0.9238 - val_loss: 0.4066 - val_accuracy: 0.9333
# Epoch 85/100
# 53/53 [==============================] - 0s 3ms/step - loss: 0.4059 - accuracy: 0.8952 - val_loss: 0.4047 - val_accuracy: 0.9333
# Epoch 86/100
# 53/53 [==============================] - 0s 3ms/step - loss: 0.4071 - accuracy: 0.8762 - val_loss: 0.4031 - val_accuracy: 0.9333
# Epoch 87/100
# 53/53 [==============================] - 0s 3ms/step - loss: 0.4025 - accuracy: 0.9048 - val_loss: 0.4013 - val_accuracy: 0.9333
# Epoch 88/100
# 53/53 [==============================] - 0s 3ms/step - loss: 0.4007 - accuracy: 0.9143 - val_loss: 0.3990 - val_accuracy: 0.9333
# Epoch 89/100
# 53/53 [==============================] - 0s 3ms/step - loss: 0.3978 - accuracy: 0.8952 - val_loss: 0.3976 - val_accuracy: 0.9333
# Epoch 90/100
# 53/53 [==============================] - 0s 3ms/step - loss: 0.3952 - accuracy: 0.9048 - val_loss: 0.3953 - val_accuracy: 0.9333
# Epoch 91/100
# 53/53 [==============================] - 0s 3ms/step - loss: 0.3934 - accuracy: 0.8952 - val_loss: 0.3930 - val_accuracy: 0.9333
# Epoch 92/100
# 53/53 [==============================] - 0s 3ms/step - loss: 0.3929 - accuracy: 0.9143 - val_loss: 0.3909 - val_accuracy: 0.9556
# Epoch 93/100
# 53/53 [==============================] - 0s 3ms/step - loss: 0.3994 - accuracy: 0.9048 - val_loss: 0.3892 - val_accuracy: 0.9333
# Epoch 94/100
# 53/53 [==============================] - 0s 3ms/step - loss: 0.3913 - accuracy: 0.8762 - val_loss: 0.3871 - val_accuracy: 0.9556
# Epoch 95/100
# 53/53 [==============================] - 0s 4ms/step - loss: 0.3868 - accuracy: 0.9143 - val_loss: 0.3853 - val_accuracy: 0.9556
# Epoch 96/100
# 53/53 [==============================] - 0s 3ms/step - loss: 0.3839 - accuracy: 0.9143 - val_loss: 0.3840 - val_accuracy: 0.9333
# Epoch 97/100
# 53/53 [==============================] - 0s 3ms/step - loss: 0.3826 - accuracy: 0.8952 - val_loss: 0.3826 - val_accuracy: 0.9333
# Epoch 98/100
# 53/53 [==============================] - 0s 3ms/step - loss: 0.3815 - accuracy: 0.8952 - val_loss: 0.3804 - val_accuracy: 0.9333
# Epoch 99/100
# 53/53 [==============================] - 0s 3ms/step - loss: 0.3820 - accuracy: 0.9143 - val_loss: 0.3792 - val_accuracy: 0.9333
# Epoch 100/100
# 53/53 [==============================] - 0s 3ms/step - loss: 0.3781 - accuracy: 0.9048 - val_loss: 0.3769 - val_accuracy: 0.9333
# 2/2 [==============================] - 0s 3ms/step - loss: 0.3769 - accuracy: 0.9333
#
#  테스트 loss: 0.3769
# 2/2 [==============================] - 0s 3ms/step - loss: 0.3769 - accuracy: 0.9333
#
#  테스트 accuracy: 0.9333

# %%
import matplotlib.pyplot as plt
history_dict = history.history
history_dict.keys()
acc = history_dict['accuracy']
val_acc = history_dict['val_accuracy']
loss = history_dict['loss']
val_loss = history_dict['val_loss']

epochs = range(1, len(acc) + 1)

# "bo"는 "파란색 점"입니다
plt.plot(epochs, loss, 'ro', label='Training loss')
# b는 "파란 실선"입니다
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

plt.clf()   # 그림을 초기화합니다
plt.plot(epochs, acc, 'r', label='Training acc')
plt.plot(epochs, val_acc, 'y', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
###예측 시각화
def plot_value_array(i, predictions_array, true_label):
  true_label = true_label[i]
  plt.grid(False)
  plt.xticks(range(3),class_names,rotation=15)

  thisplot = plt.bar(range(3), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)
  title_font = {
      'fontsize': 10,
  }
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'


  plt.title("{}. {} {:2.0f}% ({})".format(i,class_names[predicted_label],
                                100*np.max(predictions_array),
                                class_names[true_label]),
                                color=color,fontdict=title_font)
  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')




predictions=model.predict(x_test)

####0~24
num_rows = 5
num_cols = 5
num_table = num_rows*num_cols
plt.figure(figsize=(2*num_cols, 2*num_rows))
for i in range(num_table):
    plt.subplot(num_rows, num_cols,i+1)
    plot_value_array(i, predictions[i], y_test)
plt.tight_layout()
plt.show()


####25~44
num_rows = 4
num_cols = 5
num_table = num_rows*num_cols
plt.figure(figsize=(2*num_cols, 2*num_rows))
for i in range(num_table):
    plt.subplot(num_rows, num_cols,i+1)
    plot_value_array(i+25, predictions[i+25], y_test)
    if i>=19:
        break
plt.tight_layout()
plt.show()

from sklearn.metrics import classification_report
result=[np.argmax(x) for x in predictions]
print(classification_report( result, y_test))
# Out:
# 2/2 [==============================] - 0s 2ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        15
#            1       0.87      0.93      0.90        14
#            2       0.93      0.88      0.90        16
#
#     accuracy                           0.93        45
#    macro avg       0.93      0.93      0.93        45
# weighted avg       0.93      0.93      0.93        45
